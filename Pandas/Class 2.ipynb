# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pls

# %%
s1=pd.Series([1,2,3,4])
s2=pd.Series((1,2,3,4))
print(s1,s2,sep="\n")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s1=pd.Series([1,2,3,4],index=['a','b','c','d'],name='cnic')
s1.index.name='id'
s1
# Out:
# id
# a    1
# b    2
# c    3
# d    4
# Name: cnic, dtype: int64

# %%
s1={"a":1,"b":2,"c":3}
s1=pd.Series(s1)
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[[1,'Ali','A.I',1500],
     [2,'Asif','AIoT',1500],
      [3,'Hamza','CNC',1500],
     [4,'Kashid','AI',1500]]

# %%
df1=pd.DataFrame(data)
df1
# Out:
#    0       1     2     3
# 0  1     Ali   A.I  1500
# 1  2    Asif  AIoT  1500
# 2  3   Hamza   CNC  1500
# 3  4  Kashid    AI  1500

# %%
df1=pd.DataFrame(data,columns=["Id","Name","Course","Fee"])
df1
# Out:
#    Id    Name Course   Fee
# 0   1     Ali    A.I  1500
# 1   2    Asif   AIoT  1500
# 2   3   Hamza    CNC  1500
# 3   4  Kashid     AI  1500

# %%
data=[(1,'Ali','A.I',1500),
     (2,'Asif','AIoT',1500),
      (3,'Hamza','CNC',1500),
     (4,'Kashid','AI',1500)]
df1=pd.DataFrame(data,columns=["Sid","Name","Course","Fee"])
df1
# Out:
#    Sid    Name Course   Fee
# 0    1     Ali    A.I  1500
# 1    2    Asif   AIoT  1500
# 2    3   Hamza    CNC  1500
# 3    4  Kashid     AI  1500

# %% [markdown]
# # Dictionary to df

# %%
d1={
    "id":[1,2,3,4],
    "Name":["Asif","Kashif","Junaid","Qasim"],
    "Course":["A.I","AIoT","CNC",np.nan]
}
df1=pd.DataFrame(d1)
df1
# Out:
#    id    Name Course
# 0   1    Asif    A.I
# 1   2  Kashif   AIoT
# 2   3  Junaid    CNC
# 3   4   Qasim    NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
# id        4 non-null int64
# Name      4 non-null object
# Course    3 non-null object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df1.describe()
# Out:
#              id
# count  4.000000
# mean   2.500000
# std    1.290994
# min    1.000000
# 25%    1.750000
# 50%    2.500000
# 75%    3.250000
# max    4.000000

# %%
df1.dtypes
# Out:
# id         int64
# Name      object
# Course    object
# dtype: object

# %%
df1.id
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: id, dtype: int64

# %%
df1.Course
# Out:
# 0     A.I
# 1    AIoT
# 2     CNC
# 3     NaN
# Name: Course, dtype: object

# %%
df1['student fee']=0
df1
# Out:
#    id    Name Course  student fee
# 0   1    Asif    A.I            0
# 1   2  Kashif   AIoT            0
# 2   3  Junaid    CNC            0
# 3   4   Qasim    NaN            0

# %%
df1["student fee"]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# Name: student fee, dtype: int64

# %% [markdown]
# # Apply and Map

# %%
d1={"A.I":1000,
   "AIoT":2000,
   "CNC":3000}
d1
# Out:
# {'A.I': 1000, 'AIoT': 2000, 'CNC': 3000}

# %%
df1
# Out:
#    id    Name Course  student fee
# 0   1    Asif    A.I            0
# 1   2  Kashif   AIoT            0
# 2   3  Junaid    CNC            0
# 3   4   Qasim    NaN            0

# %%
df1.Course.map(d1)
# Out:
# 0    1000.0
# 1    2000.0
# 2    3000.0
# 3       NaN
# Name: Course, dtype: float64

# %%
df1['student fee']=df1.Course.map(d1)
df1
# Out:
#    id    Name Course  student fee
# 0   1    Asif    A.I       1000.0
# 1   2  Kashif   AIoT       2000.0
# 2   3  Junaid    CNC       3000.0
# 3   4   Qasim    NaN          NaN

# %% [markdown]
# # Apply (Function)

# %%
def fee_update(x):
    if x=="A.I":
        return 1200
    elif x=="AIoT":
        return 1500
    elif x=="CNC":
        return 2000
    else:
        return 0
    
df1.Course.apply(fee_update)
# Out:
# 0    1200
# 1    1500
# 2    2000
# 3       0
# Name: Course, dtype: int64

# %%
df1['updated fee']=df1.Course.apply(fee_update)
df1
# Out:
#    id    Name Course  student fee  updated fee
# 0   1    Asif    A.I       1000.0         1200
# 1   2  Kashif   AIoT       2000.0         1500
# 2   3  Junaid    CNC       3000.0         2000
# 3   4   Qasim    NaN          NaN            0

# %%
a=np.random.randint(1,100,size=(4,5))
a
# Out:
# array([[83, 41, 61,  6, 10],
#        [29, 96, 33, 82, 85],
#        [13, 31, 93, 64, 47],
#        [22,  2, 70, 52, 22]])

# %%
df2=pd.DataFrame(a,columns=["c1","c2","c3","c4","c5"])
df2
# Out:
#    c1  c2  c3  c4  c5
# 0  83  41  61   6  10
# 1  29  96  33  82  85
# 2  13  31  93  64  47
# 3  22   2  70  52  22

# %% [markdown]
# ## pd.concat
# * axis=0 (row wise)
# * axis (column wise)

# %%
df=pd.concat([df1,df2],sort=False)
df
# Out:
#     id    Name Course  student fee  updated fee    c1    c2    c3    c4    c5
# 0  1.0    Asif    A.I       1000.0       1200.0   NaN   NaN   NaN   NaN   NaN
# 1  2.0  Kashif   AIoT       2000.0       1500.0   NaN   NaN   NaN   NaN   NaN
# 2  3.0  Junaid    CNC       3000.0       2000.0   NaN   NaN   NaN   NaN   NaN
# 3  4.0   Qasim    NaN          NaN          0.0   NaN   NaN   NaN   NaN   NaN
# 0  NaN     NaN    NaN          NaN          NaN  83.0  41.0  61.0   6.0  10.0
# 1  NaN     NaN    NaN          NaN          NaN  29.0  96.0  33.0  82.0  85.0
# 2  NaN     NaN    NaN          NaN          NaN  13.0  31.0  93.0  64.0  47.0
# 3  NaN     NaN    NaN          NaN          NaN  22.0   2.0  70.0  52.0  22.0

# %%
df=pd.concat([df1,df2],axis=1)
df
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22

# %%
df["Obtained Marks"]=df.c1+df.c2+df.c3+df.c4+df.c5
df
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks
# 0             201
# 1             325
# 2             248
# 3             168

# %%
df[['Course','c1','c2','c3','c4','c5']]
# Out:
#   Course  c1  c2  c3  c4  c5
# 0    A.I  83  41  61   6  10
# 1   AIoT  29  96  33  82  85
# 2    CNC  13  31  93  64  47
# 3    NaN  22   2  70  52  22

# %%
#A.I->sum
#AIoT->product
#cnc ->commulative sum
#else -> 0
def custom_fn(x1,*l1):
    if x1=="A.I":
        return np.sum(l1)
    elif x1=="AIoT":
        return np.product(l1)
    elif x1=="CNC":
        return sum(np.cumsum(l1))
    else:
        return 0

# %%
df["Check Validation"]=df[['Course','c1','c2','c3','c4','c5']].apply(lambda x:custom_fn(*x),axis=1)

# %%
df
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks  Check Validation
# 0             201               201
# 1             325         640347840
# 2             248               643
# 3             168                 0

# %% [markdown]
# # sort function
# * sort by index
# * sort by values

# %%
df
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks  Check Validation
# 0             201               201
# 1             325         640347840
# 2             248               643
# 3             168                 0

# %%
df.sort_index()
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks  Check Validation
# 0             201               201
# 1             325         640347840
# 2             248               643
# 3             168                 0

# %%
df.sort_index(ascending=False)
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
#
#    Obtained Marks  Check Validation
# 3             168                 0
# 2             248               643
# 1             325         640347840
# 0             201               201

# %%
df.sort_index(axis=1)
# Out:
#    Check Validation Course    Name  Obtained Marks  c1  c2  c3  c4  c5  id  \
# 0               201    A.I    Asif             201  83  41  61   6  10   1
# 1         640347840   AIoT  Kashif             325  29  96  33  82  85   2
# 2               643    CNC  Junaid             248  13  31  93  64  47   3
# 3                 0    NaN   Qasim             168  22   2  70  52  22   4
#
#    student fee  updated fee
# 0       1000.0         1200
# 1       2000.0         1500
# 2       3000.0         2000
# 3          NaN            0

# %%
df.sort_values('Name')
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks  Check Validation
# 0             201               201
# 2             248               643
# 1             325         640347840
# 3             168                 0

# %%
df.sort_values(by=['Course','Obtained Marks'],ascending=[True,False])
# Out:
#    id    Name Course  student fee  updated fee  c1  c2  c3  c4  c5  \
# 0   1    Asif    A.I       1000.0         1200  83  41  61   6  10
# 1   2  Kashif   AIoT       2000.0         1500  29  96  33  82  85
# 2   3  Junaid    CNC       3000.0         2000  13  31  93  64  47
# 3   4   Qasim    NaN          NaN            0  22   2  70  52  22
#
#    Obtained Marks  Check Validation
# 0             201               201
# 1             325         640347840
# 2             248               643
# 3             168                 0

# %%
df1=pd.read_csv("./data/titanic/train.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # Group By

# %%
df1.groupby(by=['Survived','Sex']).agg(['count'])
# Out:
#                 PassengerId Pclass  Name   Age SibSp Parch Ticket  Fare Cabin  \
#                       count  count count count count count  count count count
# Survived Sex
# 0        female          81     81    81    64    81    81     81    81     6
#          male           468    468   468   360   468   468    468   468    62
# 1        female         233    233   233   197   233   233    233   233    91
#          male           109    109   109    93   109   109    109   109    45
#
#                 Embarked
#                    count
# Survived Sex
# 0        female       81
#          male        468
# 1        female      231
#          male        109

# %%
a=df1.groupby(by=['Survived','Sex'])[["PassengerId","Pclass"]].agg(['count','sum',min])

# %%
a
# Out:
#                 PassengerId             Pclass
#                       count     sum min  count   sum min
# Survived Sex
# 0        female          81   35223  15     81   231   1
#          male           468  210189   1    468  1159   1
# 1        female         233  100120   2    233   447   1
#          male           109   51854  18    109   220   1

# %%
a.index
# Out:
# MultiIndex([(0, 'female'),
#             (0,   'male'),
#             (1, 'female'),
#             (1,   'male')],
#            names=['Survived', 'Sex'])
